# %% [markdown]
# <a href="https://colab.research.google.com/github/tontantip/DADS6001-Applied-statistics/blob/main/in%20class/Reg1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
wi <-c(43,55,67,38,49,70,80,62,73,83)
js <-c(4,5,6,4,5,7,9,5,6,9)

cor.test(wi,js,method = c("pearson"), alternatives= "two.sided")
# Out:
# 	Pearson's product-moment correlation
#
# data:  wi and js
# t = 6.3644, df = 8, p-value = 0.0002172
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6692723 0.9797392
# sample estimates:
#       cor
# 0.9138219

# %%
plot(wi,js)
# Out:
# plot without title

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
age<-c(4,3,2,4,3,5,5,4,2,3)
mcost<-c(148,145,128,143,133,159,154,142,118,127)
data_table <- data.frame(age,mcost)
data_table
# Out:
#    age mcost
# 1  4   148
# 2  3   145
# 3  2   128
# 4  4   143
# 5  3   133
# 6  5   159
# 7  5   154
# 8  4   142
# 9  2   118
# 10 3   127

# %%
plot(data_table)
# Out:
# plot without title

# %%
model <- lm(mcost ~ age, data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = mcost ~ age, data = data_table)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.248 -2.902 -1.652  2.919 10.752
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  101.533      6.360  15.963 2.38e-07 ***
# age           10.905      1.744   6.253 0.000245 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.651 on 8 degrees of freedom
# Multiple R-squared:  0.8301,	Adjusted R-squared:  0.8089
# F-statistic: 39.09 on 1 and 8 DF,  p-value: 0.000245

# %% [markdown]
# predict age = 3.5

# %%
new.age<-data.frame(age= 3.5)
predict(model, newdata = new.age)
# Out:
#     1
# 139.7

# %% [markdown]
# หาค่า ค่าเฉลี่ยของ mcost ที่ X = 3.5 และ ค่าเฉลี่ยแบบช่วง

# %%
predict(model, newdata = new.age, interval = "confidence")
# Out:
#   fit   lwr      upr
# 1 139.7 135.5789 143.8211

# %% [markdown]
# หาค่า ค่าพยากรณ์ของ mcost ที่ X = 3.5 และ ค่าพยากรณ์แบบช่วง:

# %%
predict(model, newdata = new.age, interval = "prediction")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
h <- c(
    165.8, 169.8, 170.7, 170.9, 157.5, 165.9, 158.7, 166.0, 158.7,
    161.5, 167.3, 167.4, 159.2, 170.0, 166.3, 169.0, 156.2,
    159.6, 155.0, 161.1, 170.3, 167.8, 163.1, 165.8, 175.4,
    159.8, 166.0, 161.2, 160.4, 164.3, 165.5, 167.2, 167.2
)

# 2. สร้าง Vector สำหรับข้อมูล 'Forearm (cm.)'
f <- c(
    28.1, 29.1, 29.5, 28.2, 27.3, 29.0, 27.8, 26.9, 27.1,
    27.8, 27.3, 30.1, 27.3, 30.9, 28.8, 28.8, 25.6,
    25.4, 26.6, 26.6, 29.3, 28.6, 26.9, 26.3, 30.1,
    27.1, 28.1, 29.2, 27.8, 27.8, 28.6, 27.1, 29.7
)

data_table <- data.frame(h,f)
data_table
# Out:
#    h     f
# 1  165.8 28.1
# 2  169.8 29.1
# 3  170.7 29.5
# 4  170.9 28.2
# 5  157.5 27.3
# 6  165.9 29.0
# 7  158.7 27.8
# 8  166.0 26.9
# 9  158.7 27.1
# 10 161.5 27.8
# 11 167.3 27.3
# 12 167.4 30.1
# 13 159.2 27.3
# 14 170.0 30.9
# 15 166.3 28.8
# 16 169.0 28.8
# 17 156.2 25.6
# 18 159.6 25.4
# 19 155.0 26.6
# 20 161.1 26.6
# 21 170.3 29.3
# 22 167.8 28.6
# 23 163.1 26.9
# 24 165.8 26.3
# 25 175.4 30.1
# 26 159.8 27.1
# 27 166.0 28.1
# 28 161.2 29.2
# 29 160.4 27.8
# 30 164.3 27.8
# 31 165.5 28.6
# 32 167.2 27.1
# 33 167.2 29.7

# %%
plot(data_table)
# Out:
# plot without title

# %%
model <- lm(h~f,data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = h ~ f, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3993 -2.4847  0.2135  2.4335  5.8826
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  92.2093    13.4453   6.858 1.10e-07 ***
# f             2.5818     0.4793   5.387 7.08e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.572 on 31 degrees of freedom
# Multiple R-squared:  0.4835,	Adjusted R-squared:  0.4669
# F-statistic: 29.02 on 1 and 31 DF,  p-value: 7.076e-06

# %%
new_f <- data.frame(f = 30)
predict(model, newdata = new_f)
# Out:
#        1
# 169.6647

# %%
predict(model , newdata = new_f, interval = "confidence")
# Out:
#   fit      lwr      upr
# 1 169.6647 167.3543 171.9752

# %%
predict(model, newdata = new_f, interval = "prediction")
# Out:
#   fit      lwr      upr
# 1 169.6647 162.0213 177.3082

# %%
xi <- c(43,55,67,38,49,70,80,62,73,83)

yi <- c(4,5,6,4,5,7,9,5,6,9)

cor.test(xi,yi, method = "pearson" , alternatives = "two.sided")
# Out:
# 	Pearson's product-moment correlation
#
# data:  xi and yi
# t = 6.3644, df = 8, p-value = 0.0002172
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6692723 0.9797392
# sample estimates:
#       cor
# 0.9138219

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)
plot(x,y)
# Out:
# plot without title

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table <- data.frame(x,y)
model <- lm(y~x,data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9394 -0.9763  0.2829  0.9950  2.6644
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.14684    1.12131   8.157 1.63e-09 ***
# x            0.48147    0.05967   8.069 2.09e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.678 on 34 degrees of freedom
# Multiple R-squared:  0.6569,	Adjusted R-squared:  0.6468
# F-statistic:  65.1 on 1 and 34 DF,  p-value: 2.089e-09

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

cor.test(x,y,method = "pearson", alternative = "two.sided")
# Out:
# 	Pearson's product-moment correlation
#
# data:  x and y
# t = 8.0685, df = 34, p-value = 2.089e-09
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6568805 0.8995161
# sample estimates:
#       cor
# 0.8105027

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table = data.frame(x,y)
model <- aov(y~x,data = data_table)
summary(model)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# x            1  183.2  183.24    65.1 2.09e-09 ***
# Residuals   34   95.7    2.81
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table = data.frame(x,y)
model <- lm(y~x,data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9394 -0.9763  0.2829  0.9950  2.6644
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.14684    1.12131   8.157 1.63e-09 ***
# x            0.48147    0.05967   8.069 2.09e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.678 on 34 degrees of freedom
# Multiple R-squared:  0.6569,	Adjusted R-squared:  0.6468
# F-statistic:  65.1 on 1 and 34 DF,  p-value: 2.089e-09

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table <- data.frame(x,y)

model <- lm(y~x,data = data_table)
new_data <- data.frame(x = 20)
prediction <- predict(model , newdata = new_data , interval = "confidence", level= 0.90)
prediction
# Out:
#   fit      lwr      upr
# 1 18.77632 18.26972 19.28293

# %%
height<-c(165.8,169.8,170.7,170.9,157.5,165.9,158.7,166,158.7,161.5,167.3,167.4,159.2,170,166.3,169,156.2,159.6,155,161.1,170.3,167.8,163.1,165.8,175.4,159.8,166,161.2,160.4,164.3,165.5,167.2,167.2)
forearm<-c(28.1,29.1,29.5,28.2,27.3,29,27.8,26.9,27.1,27.8,27.3,30.1,27.3,30.9,28.8,28.8,25.6,25.4,26.6,26.6,29.3,28.6,
26.9,26.3,30.1,27.1,28.1,29.2,27.8,27.8,28.6,27.1,29.7)

## plot graph scatter
plot(height, forearm)
data_table <- data.frame(height,forearm)

model <- lm(height ~ forearm , data = data_table)
summary(model)

plot(model)
# Out:
# Call:
# lm(formula = height ~ forearm, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3993 -2.4847  0.2135  2.4335  5.8826
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  92.2093    13.4453   6.858 1.10e-07 ***
# forearm       2.5818     0.4793   5.387 7.08e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.572 on 31 degrees of freedom
# Multiple R-squared:  0.4835,	Adjusted R-squared:  0.4669
# F-statistic: 29.02 on 1 and 31 DF,  p-value: 7.076e-06
# plot without title
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
# 1. นำเข้าข้อมูล (แก้ไขค่า 69 เป็น 169 แล้ว)
height <- c(165.8,169.8,170.7,170.9,157.5,165.9,158.7,166,158.7,161.5,
            167.3,167.4,159.2,170,166.3,169.0,156.2,159.6,155,161.1,
            170.3,167.8,163.1,165.8,175.4,159.8,166,161.2,160.4,164.3,
            165.5,167.2,167.2)

forearm <- c(28.1,29.1,29.5,28.2,27.3,29,27.8,26.9,27.1,27.8,
             27.3,30.1,27.3,30.9,28.8,28.8,25.6,25.4,26.6,26.6,
             29.3,28.6,26.9,26.3,30.1,27.1,28.1,29.2,27.8,27.8,
             28.6,27.1,29.7)

# สร้าง Data Frame
data_test <- data.frame(height, forearm)

# 2. สร้าง Linear Regression Model
# สมมติให้ Forearm (y) ขึ้นอยู่กับ Height (x)
model <- lm(forearm ~ height, data = data_test)

# 3. สั่งวาดกราฟตรวจสอบข้อสมมุติ 4 รูปมาตรฐาน
par(mfrow = c(2, 2)) # จัดหน้าจอเป็น 4 ช่อง
plot(model)
par(mfrow = c(1, 1)) # คืนค่าหน้าจอปกติ

# 4. (แถม) ทดสอบ Normality ด้วยสถิติ (Shapiro-Wilk test)
shapiro_result <- shapiro.test(residuals(model))
print(shapiro_result)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(model)
# W = 0.96721, p-value = 0.4073
# Plot with title “”

# %%
# 1. นำเข้าข้อมูล (แก้ไขค่า 69 เป็น 169 แล้ว)
height <- c(165.8,169.8,170.7,170.9,157.5,165.9,158.7,166,158.7,161.5,
            167.3,167.4,159.2,170,166.3,169.0,156.2,159.6,155,161.1,
            170.3,167.8,163.1,165.8,175.4,159.8,166,161.2,160.4,164.3,
            165.5,167.2,167.2)

forearm <- c(28.1,29.1,29.5,28.2,27.3,29,27.8,26.9,27.1,27.8,
             27.3,30.1,27.3,30.9,28.8,28.8,25.6,25.4,26.6,26.6,
             29.3,28.6,26.9,26.3,30.1,27.1,28.1,29.2,27.8,27.8,
             28.6,27.1,29.7)

# สร้าง Data Frame
data_test <- data.frame(height, forearm)

# 2. สร้าง Linear Regression Model
# สมมติให้ Forearm (y) ขึ้นอยู่กับ Height (x)
model <- lm(forearm ~ height, data = data_test)
plot(forearm , height)
plot(model)
# Out:
# plot without title
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
height <- c(165.8,169.8,170.7,170.9,157.5,165.9,158.7,166,158.7,161.5,
            167.3,167.4,159.2,170,166.3,169.0,156.2,159.6,155,161.1,
            170.3,167.8,163.1,165.8,175.4,159.8,166,161.2,160.4,164.3,
            165.5,167.2,167.2)

forearm <- c(28.1,29.1,29.5,28.2,27.3,29,27.8,26.9,27.1,27.8,
             27.3,30.1,27.3,30.9,28.8,28.8,25.6,25.4,26.6,26.6,
             29.3,28.6,26.9,26.3,30.1,27.1,28.1,29.2,27.8,27.8,
             28.6,27.1,29.7)

# สร้าง Data Frame
data_test <- data.frame(height, forearm)

# 2. สร้าง Linear Regression Model
# สมมติให้ Forearm (y) ขึ้นอยู่กับ Height (x)
model <- lm(forearm ~ height, data = data_test)

cook <- cooks.distance(model)
plot(cook)
# Out:
# plot without title

# %%
height <- c(165.8,169.8,170.7,170.9,157.5,165.9,158.7,166,158.7,161.5,
            167.3,167.4,159.2,170,166.3,169.0,156.2,159.6,155,161.1,
            170.3,167.8,163.1,165.8,175.4,159.8,166,161.2,160.4,164.3,
            165.5,167.2,167.2)

forearm <- c(28.1,29.1,29.5,28.2,27.3,29,27.8,26.9,27.1,27.8,
             27.3,30.1,27.3,30.9,28.8,28.8,25.6,25.4,26.6,26.6,
             29.3,28.6,26.9,26.3,30.1,27.1,28.1,29.2,27.8,27.8,
             28.6,27.1,29.7)

# สร้าง Data Frame
data_test <- data.frame(height, forearm)

# 2. สร้าง Linear Regression Model
# สมมติให้ Forearm (y) ขึ้นอยู่กับ Height (x)
model <- lm(forearm ~ height, data = data_test)

# %%
install.packages("car")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘colorspace’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’, ‘cowplot’, ‘Deriv’, ‘forecast’, ‘microbenchmark’, ‘rbibutils’, ‘numDeriv’, ‘doBy’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘reformulas’, ‘Rdpack’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘Formula’, ‘pbkrtest’, ‘quantreg’, ‘lme4’

# %%
age <- c(4,3,2,4,3,5,5,4,2,3)
cost <- c(148,145,128,143,133,159,154,142,118,127)
data_table <- data.frame(age, cost)

model <- lm(cost ~ age, data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = cost ~ age, data = data_table)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.248 -2.902 -1.652  2.919 10.752
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  101.533      6.360  15.963 2.38e-07 ***
# age           10.905      1.744   6.253 0.000245 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.651 on 8 degrees of freedom
# Multiple R-squared:  0.8301,	Adjusted R-squared:  0.8089
# F-statistic: 39.09 on 1 and 8 DF,  p-value: 0.000245

# %%
age <- c(4,3,2,4,3,5,5,4,2,3)
cost <- c(148,145,128,143,133,159,154,142,118,127)
data_table <- data.frame(age, cost)
model <- lm(cost ~ age, data = data_table)
## สร้าง prediction
new_data <- data.frame(age = 3.5)
prediction <- predict(model, newdata = new_data, interval = "prediction")
prediction
# Out:
#   fit   lwr      upr
# 1 139.7 126.0318 153.3682

# %%
h <- c(
    165.8, 169.8, 170.7, 170.9, 157.5, 165.9, 158.7, 166.0, 158.7,
    161.5, 167.3, 167.4, 159.2, 170.0, 166.3, 169.0, 156.2,
    159.6, 155.0, 161.1, 170.3, 167.8, 163.1, 165.8, 175.4,
    159.8, 166.0, 161.2, 160.4, 164.3, 165.5, 167.2, 167.2
)

# 2. สร้าง Vector สำหรับข้อมูล 'Forearm (cm.)'
f <- c(
    28.1, 29.1, 29.5, 28.2, 27.3, 29.0, 27.8, 26.9, 27.1,
    27.8, 27.3, 30.1, 27.3, 30.9, 28.8, 28.8, 25.6,
    25.4, 26.6, 26.6, 29.3, 28.6, 26.9, 26.3, 30.1,
    27.1, 28.1, 29.2, 27.8, 27.8, 28.6, 27.1, 29.7)

data_table <- data.frame(h,f)
model <- aov(h~f, data = data_table)
summary(model)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# f            1  370.4   370.4   29.02 7.08e-06 ***
# Residuals   31  395.6    12.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
h <- c(
    165.8, 169.8, 170.7, 170.9, 157.5, 165.9, 158.7, 166.0, 158.7,
    161.5, 167.3, 167.4, 159.2, 170.0, 166.3, 169.0, 156.2,
    159.6, 155.0, 161.1, 170.3, 167.8, 163.1, 165.8, 175.4,
    159.8, 166.0, 161.2, 160.4, 164.3, 165.5, 167.2, 167.2
)

# 2. สร้าง Vector สำหรับข้อมูล 'Forearm (cm.)'
f <- c(
    28.1, 29.1, 29.5, 28.2, 27.3, 29.0, 27.8, 26.9, 27.1,
    27.8, 27.3, 30.1, 27.3, 30.9, 28.8, 28.8, 25.6,
    25.4, 26.6, 26.6, 29.3, 28.6, 26.9, 26.3, 30.1,
    27.1, 28.1, 29.2, 27.8, 27.8, 28.6, 27.1, 29.7)

data_table <- data.frame(h,f)
model <- lm(h~f, data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = h ~ f, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3993 -2.4847  0.2135  2.4335  5.8826
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  92.2093    13.4453   6.858 1.10e-07 ***
# f             2.5818     0.4793   5.387 7.08e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.572 on 31 degrees of freedom
# Multiple R-squared:  0.4835,	Adjusted R-squared:  0.4669
# F-statistic: 29.02 on 1 and 31 DF,  p-value: 7.076e-06

# %%
h <- c(
    165.8, 169.8, 170.7, 170.9, 157.5, 165.9, 158.7, 166.0, 158.7,
    161.5, 167.3, 167.4, 159.2, 170.0, 166.3, 169.0, 156.2,
    159.6, 155.0, 161.1, 170.3, 167.8, 163.1, 165.8, 175.4,
    159.8, 166.0, 161.2, 160.4, 164.3, 165.5, 167.2, 167.2
)

# 2. สร้าง Vector สำหรับข้อมูล 'Forearm (cm.)'
f <- c(
    28.1, 29.1, 29.5, 28.2, 27.3, 29.0, 27.8, 26.9, 27.1,
    27.8, 27.3, 30.1, 27.3, 30.9, 28.8, 28.8, 25.6,
    25.4, 26.6, 26.6, 29.3, 28.6, 26.9, 26.3, 30.1,
    27.1, 28.1, 29.2, 27.8, 27.8, 28.6, 27.1, 29.7
)

data_table <- data.frame(h,f)
model <- lm(h~f, data = data_table)

new_data <- data.frame(f = 30)
prediction <- predict(model, newdata = new_data, interval= "prediction")
prediction
# Out:
#   fit      lwr      upr
# 1 169.6647 162.0213 177.3082

# %%
h <- c(
    165.8, 169.8, 170.7, 170.9, 157.5, 165.9, 158.7, 166.0, 158.7,
    161.5, 167.3, 167.4, 159.2, 170.0, 166.3, 169.0, 156.2,
    159.6, 155.0, 161.1, 170.3, 167.8, 163.1, 165.8, 175.4,
    159.8, 166.0, 161.2, 160.4, 164.3, 165.5, 167.2, 167.2
)

# 2. สร้าง Vector สำหรับข้อมูล 'Forearm (cm.)'
f <- c(
    28.1, 29.1, 29.5, 28.2, 27.3, 29.0, 27.8, 26.9, 27.1,
    27.8, 27.3, 30.1, 27.3, 30.9, 28.8, 28.8, 25.6,
    25.4, 26.6, 26.6, 29.3, 28.6, 26.9, 26.3, 30.1,
    27.1, 28.1, 29.2, 27.8, 27.8, 28.6, 27.1, 29.7
)

data_table <- data.frame(h,f)
model <- lm(h~f, data = data_table)

new_data <- data.frame(f = 30)
prediction <- predict(model, newdata = new_data, interval= "confidenc")
prediction
# Out:
#   fit      lwr      upr
# 1 169.6647 167.3543 171.9752

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

plot(x,y)
# Out:
# plot without title

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table <- data.frame(x,y)
model <- lm(y~x,data = data_table)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data_table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9394 -0.9763  0.2829  0.9950  2.6644
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.14684    1.12131   8.157 1.63e-09 ***
# x            0.48147    0.05967   8.069 2.09e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.678 on 34 degrees of freedom
# Multiple R-squared:  0.6569,	Adjusted R-squared:  0.6468
# F-statistic:  65.1 on 1 and 34 DF,  p-value: 2.089e-09

# %%
x <- c(18.9,15.5,19.4,20,29.8,19.8,20.3,20,22,23.6,14.8,22.7,
       18.5,21.5,14.8,17.7,21,15.9,16.6,15.5,13.7,27.5,20.3,22.9,
       14.1,10.1,5.8,20.7,17.8,11.4,14.4,13.4,17.8,20.7,13.3,22.9)
y <- c(20,16.8,20.2,20,20.2,18,17.8,19.2,22.3,18.9,13.3,20.6,
        19.0,19.2,16.1,19.9,20.4,17.6,18.8,16.9,16.3,21.4,19.2,19.8,
        18.5,12.1,8,17.4,18.4,17.3,16.6,12.9,17.5,19.4,15.5,19.2)

data_table <- data.frame(x,y)

model <- lm(y~x,data = data_table)
new_data <- data.frame(x = 20)
prediction <- predict(model , newdata = new_data , interval = "confidence", level= 0.90)
prediction
# Out:
#   fit      lwr      upr
# 1 18.77632 18.26972 19.28293
